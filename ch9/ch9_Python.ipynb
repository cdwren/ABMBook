# %% [markdown]
# ### Data analysis script for NetLogo output
#
# A set of visualisations for a standard table output of NetLogo: scatterplot, barplot, and lineplot.
#
# This is an example script used in chapter 9 of Romanowska, I., Wren, C., Crabtree, S. 2021 Agent-Based Modeling for Archaeology: Simulating the Complexity of Societies. Santa Fe Institute Press.
#
# Code blocks: 9.7, 9.9, 9.11, 9.13

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
sns.set_palette("deep")
sns.set()

data = pd.read_csv('Gaul_Model experiment-table.csv', skiprows = 6)

# %%
# Check how everything looks like
data.head()
# Out:
#    [run number]  random-seed  GrainTradeRate  harvest-calories  reproduction  \
# 0             3            0              20                 4             3
# 1             7            0              20                 4             3
# 2             5            0              20                 4             3
# 3             2            0              20                 4             3
# 4             4            0              20                 4             3
#
#    buying-radius  life-expectancy  harvest-amount  number-Gauls  \
# 0             10               50              20           150
# 1             10               50              20           150
# 2             10               50              20           150
# 3             10               50              20           150
# 4             10               50              20           150
#
#    weighted-trade-choice  ...  number-mining-Gauls  Etruscan-arrival  metals?  \
# ...

# %% [markdown]
# ### SCATTERPLOT

# %%
sns.scatterplot(x = "weighted-trade-choice", y = "count turtles", data = data)

# %% [markdown]
# ### BARPLOT

# %%
plt.figure(figsize = (10,7))
sns.barplot( x = "weighted-trade-choice", y = 'count turtles', hue = 'metals?',data = data)

# %%
# read file, the first rows do not contain data
curve_data = pd.read_csv("metals_ true_repro3_13.csv", skiprows=17)

# %%
# meaningful column names
curve_data.rename(columns ={"y":"Etruscan", "y.1":"Greek" }, inplace = True)

# %%
curve_data.head()
# Out:
#     x   Etruscan  color  pen down?    x.1      Greek  color.1 pen down?.1
# 0  35   0.000000     95       True  101.0   0.000000     25.0        True
# 1  36  19.030303     95       True  102.0   3.913265     25.0        True
# 2  37  38.090909     95       True  103.0   7.459184     25.0        True
# 3  38  77.090909     95       True  104.0   6.714286     25.0        True
# 4  39  76.090909     95       True  105.0  16.367347     25.0        True

# %% [markdown]
# ### LINEPLOT Basic version

# %%
plt.figure(figsize=(15, 10))
sns.lineplot( y = "Etruscan", x = "x", data = curve_data)
sns.lineplot( y = "Greek", x = "x.1", data = curve_data)

# %% [markdown]
# ### LINEPLOT Better version

# %%
sns.set(font="CMU Bright", font_scale=1.5, style="white")
sns.set_palette("viridis")
plt.figure(figsize=(15, 10))

sns.lineplot( y = "Etruscan", x = "x", data = curve_data, label = "Etruscan Wine",linewidth = 3, color = "#440154FF")
sns.lineplot( y = "Greek", x = "x.1", data = curve_data, label = "Greek Wine", linewidth = 3, color = "#55C667FF")

plt.legend() #For the legend to work you need to add labels in the plotting command above

plt.xlabel('Year since arrival') # default axis labels were not particularly informative in this case
plt.ylabel('Wine')
plt.tight_layout()
# save figure 
plt.savefig("ch9_the_curve.png", dpi = 900)
# Out:
# findfont: Font family ['CMU Bright'] not found. Falling back to DejaVu Sans.
# findfont: Font family ['CMU Bright'] not found. Falling back to DejaVu Sans.
